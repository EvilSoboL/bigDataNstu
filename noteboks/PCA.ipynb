# %%
import sys

sys.path.append('C:\\Users\\Mark\\PycharmProjects\\bigDataNstu')

from src.data.raw_handler import show_raw_data, get_raw_data_dict_csv
from src.visualization.exploratory import show_pca_plots
from src.features.pca import get_pca_dict

# %% [markdown]
# # Исходные данные

# %%
show_raw_data()
# Out:
# 'crude_oil_steam'
#    F_fuel  F_steam         O2           CO         NO      NO2        NOx  \
# 0   0.200    1.784  10.924389  1436.467675  85.878288  3.08404  88.968459
# 1   0.216    1.784  10.924389  1436.467675  85.878288  3.08404  88.968459
# 2   0.232    1.784  10.924389  1436.311000  85.878288  3.08404  88.968459
# 3   0.248    1.784  10.918877  1435.131099  85.878288  3.08404  88.968459
# 4   0.264    1.784  10.915218  1433.974051  85.887051  3.08404  88.971090
#
#         CO2         SO2
# 0  7.820647  155.282350
# 1  7.820647  155.282350
# 2  7.820647  155.282350
# 3  7.821372  155.282350
# 4  7.825922  155.340263
# 'diesel_air'
#    F_fuel  F_air         O2          CO   NO       NO2       NOx       CO2  \
# 0   0.200  1.784  11.828453  679.846033  0.0  8.741990  8.176684  7.377569
# 1   0.216  1.784  11.828453  679.846033  0.0  8.741990  8.176684  7.377569
# 2   0.232  1.784  11.828453  679.846033  0.0  8.741990  8.176684  7.377569
# ...

# %% [markdown]
# # Графики PCA

# %%
show_pca_plots()
