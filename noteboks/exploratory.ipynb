# %%
import sys

sys.path.append('C:\\Users\\Mark\\PycharmProjects\\bigDataNstu')

from src.data.raw_handler import get_raw_data_dict_csv
from src.visualization.boxplot import BoxPlot

# %%
boxplot = BoxPlot()
boxplot.show_boxplots('O2')

# %%
boxplot.show_boxplots('CO')

# %%
boxplot.show_boxplots('NO')

# %%
boxplot.show_boxplots('NOx')
